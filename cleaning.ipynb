# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_ALL_AQI_2000_2025.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure PM2.5 AQI values are numeric and remove invalid rows
df['PM2.5 AQI Value'] = pd.to_numeric(df['PM2.5 AQI Value'], errors='coerce')
df = df.dropna(subset=['PM2.5 AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_ALL_AQI_2000_2025_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (9483, 6)
# Date                object
# PM2.5 AQI Value      int64
# Main Pollutant     float64
# Site Name           object
# Site ID             object
# Source              object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (9483, 6)
# Saved cleaned dataset to Dataset for DS Project - ATL_ALL_AQI_2000_2025_cleaned.csv
#         Date  PM2.5 AQI Value Main Pollutant         Site Name      Site ID  \
# 0 1999-01-01               84        Unknown  E. Rivers School  13-121-0032
# 1 1999-01-02               68        Unknown  E. Rivers School  13-121-0032
# 2 1999-01-03               63        Unknown         Doraville  13-089-2001
# 3 1999-01-04               61        Unknown         Doraville  13-089-2001
# 4 1999-01-05                8        Unknown  E. Rivers School  13-121-0032
#
#   Source
# 0    AQS
# 1    AQS
# 2    AQS
# 3    AQS
# 4    AQS

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_CO_2000_2025.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure Carbon Monoxide AQI values are numeric and remove invalid rows
df['Carbon Monoxide AQI Value'] = pd.to_numeric(df['Carbon Monoxide AQI Value'], errors='coerce')
df = df.dropna(subset=['Carbon Monoxide AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_CO_2000_2025_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (9489, 6)
# Date                          object
# Carbon Monoxide AQI Value      int64
# Main Pollutant               float64
# Site Name                     object
# Site ID                       object
# Source                        object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (9489, 6)
# Saved cleaned dataset to Dataset for DS Project - ATL_CO_2000_2025_cleaned.csv
#         Date  Carbon Monoxide AQI Value Main Pollutant  \
# 0 2000-01-01                         34        Unknown
# 1 2000-01-02                         14        Unknown
# 2 2000-01-03                         20        Unknown
# 3 2000-01-04                          8        Unknown
# 4 2000-01-05                         24        Unknown
#
#                                            Site Name      Site ID Source
# 0                                      Not Available  13-089-1002    AQS
# 1                                      Not Available  13-089-1002    AQS
# ...

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_ozone_2000_2025.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure Ozone AQI values are numeric and remove invalid rows
df['Ozone AQI Value'] = pd.to_numeric(df['Ozone AQI Value'], errors='coerce')
df = df.dropna(subset=['Ozone AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_ozone_2000_2025_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (9467, 6)
# Date                object
# Ozone AQI Value      int64
# Main Pollutant     float64
# Site Name           object
# Site ID             object
# Source              object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (9467, 6)
# Saved cleaned dataset to Dataset for DS Project - ATL_ozone_2000_2025_cleaned.csv
#         Date  Ozone AQI Value Main Pollutant        Site Name      Site ID  \
# 0 2000-01-01               35        Unknown  Georgia Station  13-231-9991
# 1 2000-01-02               31        Unknown  Georgia Station  13-231-9991
# 2 2000-01-03               39        Unknown  Georgia Station  13-231-9991
# 3 2000-01-04               38        Unknown  Georgia Station  13-231-9991
# 4 2000-01-05               21        Unknown  Georgia Station  13-231-9991
#
#   Source
# 0    AQS
# 1    AQS
# 2    AQS
# 3    AQS
# 4    AQS

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - LA_CO.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure Carbon Monoxide AQI values are numeric and remove invalid rows
df['Carbon Monoxide AQI Value'] = pd.to_numeric(df['Carbon Monoxide AQI Value'], errors='coerce')
df = df.dropna(subset=['Carbon Monoxide AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - LA_CO_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (13150, 6)
# Date                         object
# Carbon Monoxide AQI Value    object
# Main Pollutant               object
# Site Name                    object
# Site ID                      object
# Source                       object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (13149, 6)
# Saved cleaned dataset to Dataset for DS Project - LA_CO_cleaned.csv
#         Date  Carbon Monoxide AQI Value Main Pollutant Site Name      Site ID  \
# 0 1990-01-01                        121        Unknown    Reseda  06-037-1201
# 1 1990-01-02                         39        Unknown    Pomona  06-037-1701
# 2 1990-01-03                         89        Unknown   Lynwood  06-037-1301
# 3 1990-01-04                        128        Unknown   Lynwood  06-037-1301
# 4 1990-01-05                        148        Unknown   Lynwood  06-037-1301
#
#   Source
# 0    AQS
# 1    AQS
# 2    AQS
# 3    AQS
# 4    AQS

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - LA_NO2.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure Nitrogen Dioxide AQI values are numeric and remove invalid rows
df['Nitrogen Dioxide AQI Value'] = pd.to_numeric(df['Nitrogen Dioxide AQI Value'], errors='coerce')
df = df.dropna(subset=['Nitrogen Dioxide AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - LA_NO2_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (13150, 6)
# Date                          object
# Nitrogen Dioxide AQI Value    object
# Main Pollutant                object
# Site Name                     object
# Site ID                       object
# Source                        object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (13149, 6)
# Saved cleaned dataset to Dataset for DS Project - LA_NO2_cleaned.csv
#         Date  Nitrogen Dioxide AQI Value Main Pollutant      Site Name  \
# 0 1990-01-01                         105        Unknown      Hawthorne
# 1 1990-01-02                          68        Unknown      Hawthorne
# 2 1990-01-03                          79        Unknown      Hawthorne
# 3 1990-01-04                         105        Unknown  Not Available
# 4 1990-01-05                         112        Unknown  Not Available
#
#        Site ID Source
# 0  06-037-5001    AQS
# 1  06-037-5001    AQS
# 2  06-037-5001    AQS
# 3  06-037-2401    AQS
# ...

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - LA_ozone_layer.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Convert Date column to datetime and drop invalid dates
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Normalize missing Main Pollutant values
df['Main Pollutant'] = df['Main Pollutant'].fillna('Unknown').astype(str)

# Ensure Ozone AQI values are numeric and remove invalid rows
df['Ozone AQI Value'] = pd.to_numeric(df['Ozone AQI Value'], errors='coerce')
df = df.dropna(subset=['Ozone AQI Value'])

# Remove duplicate rows and sort dataset
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Date').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - LA_ozone_layer_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (13150, 6)
# Date               object
# Ozone AQI Value    object
# Main Pollutant     object
# Site Name          object
# Site ID            object
# Source             object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (13149, 6)
# Saved cleaned dataset to Dataset for DS Project - LA_ozone_layer_cleaned.csv
#         Date  Ozone AQI Value Main Pollutant               Site Name  \
# 0 1990-01-01               43        Unknown  Lancaster-N. Beech St.
# 1 1990-01-02               26        Unknown  Lancaster-N. Beech St.
# 2 1990-01-03               24        Unknown                Glendora
# 3 1990-01-04               25        Unknown                Glendora
# 4 1990-01-05               25        Unknown                   Azusa
#
#        Site ID Source
# 0  06-037-7001    AQS
# 1  06-037-7001    AQS
# 2  06-037-0016    AQS
# 3  06-037-0016    AQS
# 4  06-037-0002    AQS

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - LA_temperature.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# No Date column in this dataset, skip datetime conversion

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# No Main Pollutant or AQI values to normalize in this dataset

# Remove duplicate rows and sort dataset by Year
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('Year').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - LA_temperature_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (36, 4)
# Year           int64
# Rank           int64
# High (°F)    float64
# Low (°F)     float64
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (36, 4)
# Saved cleaned dataset to Dataset for DS Project - LA_temperature_cleaned.csv
#    Year  Rank  High (°F)  Low (°F)
# 0  1990    35       71.4      56.1
# 1  1991    81       69.5      55.6
# 2  1992    16       72.0      57.7
# 3  1993    27       71.3      56.8
# 4  1994    42       71.2      56.0

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_TEMP_2000_2010.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# If the CSV file already has headers, keep them.
# Otherwise use the first row as the header row.
if 'DATE' not in df.columns:
	df.columns = df.iloc[0]
	df = df[1:].reset_index(drop=True)

# Convert DATE column to datetime and drop invalid dates
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d', errors='coerce')
df = df.dropna(subset=['DATE'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Remove duplicate rows and sort dataset by DATE
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('DATE').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_TEMP_2000_2010_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (29526, 7)
# STATION     object
# NAME        object
# DATE        object
# TAVG       float64
# TMAX       float64
# TMIN       float64
# TOBS       float64
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (29526, 7)
# Saved cleaned dataset to Dataset for DS Project - ATL_TEMP_2000_2010_cleaned.csv
#        STATION                                               NAME       DATE  \
# 0  USC00096407                                    NORCROSS, GA US 2000-01-01
# 1  USW00053863            ATLANTA DEKALB PEACHTREE AIRPORT, GA US 2000-01-01
# 2  USC00090444                                ATLANTA 9 NW, GA US 2000-01-01
# 3  USC00095404                                MABLETON 1 N, GA US 2000-01-01
# 4  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO... 2000-01-01
#
#    TAVG  TMAX  TMIN  TOBS
# 0   NaN   NaN   NaN   NaN
# 1  55.0  64.0  46.0   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN  69.0  39.0  49.0
# 4  58.0  66.0  49.0   NaN

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_TEMP_2010_2020.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# Set column names based on the first row
df.columns = df.iloc[0]
df = df[1:].reset_index(drop=True)

# Convert DATE column to datetime and drop invalid dates
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d', errors='coerce')
df = df.dropna(subset=['DATE'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Remove duplicate rows and sort dataset by DATE
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('DATE').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_TEMP_2010_2020_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (90555, 7)
# Unnamed: 0    object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# Unnamed: 5    object
# Unnamed: 6    object
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (90554, 7)
# Saved cleaned dataset to Dataset for DS Project - ATL_TEMP_2010_2020_cleaned.csv
# 0      STATION                       NAME       DATE TAVG TMAX TMIN TOBS
# 0  US1GAGW0005     LILBURN 0.8 SSE, GA US 2010-01-01  NaN  NaN  NaN  NaN
# 1  USC00090444        ATLANTA 9 NW, GA US 2010-01-01  NaN  NaN  NaN  NaN
# 2  US1GACB0016     MARIETTA 8.3 NE, GA US 2010-01-01  NaN  NaN  NaN  NaN
# 3  US1GADK0002        TUCKER 2.3 W, GA US 2010-01-01  NaN  NaN  NaN  NaN
# 4  US1GAFT0019  EAST POINT 6.3 WNW, GA US 2010-01-01  NaN  NaN  NaN  NaN

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('Dataset for DS Project - ATL_TEMP_2020_2025.csv')
print("Original Shape:", df.shape)
print(df.dtypes)
df.head()

# The CSV already has proper headers, so keep the current column names
# and do not overwrite them with the first row of data.
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d', errors='coerce')
df = df.dropna(subset=['DATE'])

# Clean string columns by trimming whitespace
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].apply(lambda col: col.str.strip())

# Remove duplicate rows and sort dataset by DATE
original_rows = df.shape[0]
df = df.drop_duplicates().sort_values('DATE').reset_index(drop=True)
print(f'Dropped {original_rows - df.shape[0]} duplicate or invalid rows')

# Save cleaned dataset
output_path = 'Dataset for DS Project - ATL_TEMP_2020_2025_cleaned.csv'
df.to_csv(output_path, index=False)
print('Cleaned Shape:', df.shape)
print('Saved cleaned dataset to', output_path)
df.head()
# Out:
# Original Shape: (49530, 6)
# STATION     object
# NAME        object
# DATE        object
# TAVG       float64
# TMAX       float64
# TMIN       float64
# dtype: object
# Dropped 0 duplicate or invalid rows
# Cleaned Shape: (49530, 6)
# Saved cleaned dataset to Dataset for DS Project - ATL_TEMP_2020_2025_cleaned.csv
#        STATION                              NAME       DATE  TAVG  TMAX  TMIN
# 0  US1GACB0002              SMYRNA 2.3 NE, GA US 2020-01-01   NaN   NaN   NaN
# 1  US1GADK0007      NORTH DECATUR 3.0 NNE, GA US 2020-01-01   NaN   NaN   NaN
# 2  US1GADK0033             DECATUR 1.2 NE, GA US 2020-01-01   NaN   NaN   NaN
# 3  USW00003888  ATLANTA FULTON CO AIRPORT, GA US 2020-01-01   NaN  57.0  35.0
# 4  USC00092753            DORAVILLE 2 NNE, GA US 2020-01-01   NaN   NaN   NaN
